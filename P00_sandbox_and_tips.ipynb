# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Using-Jupyter" data-toc-modified-id="Using-Jupyter-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Using Jupyter</a></span><ul class="toc-item"><li><span><a href="#Useful-keyboard-commands" data-toc-modified-id="Useful-keyboard-commands-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Useful keyboard commands</a></span></li></ul></li><li><span><a href="#Look-up-function-doc" data-toc-modified-id="Look-up-function-doc-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Look-up function doc</a></span><ul class="toc-item"><li><span><a href="#Auto-sugestion" data-toc-modified-id="Auto-sugestion-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Auto-sugestion</a></span></li></ul></li><li><span><a href="#Tips" data-toc-modified-id="Tips-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Tips</a></span><ul class="toc-item"><li><span><a href="#Keyboard-shortcuts" data-toc-modified-id="Keyboard-shortcuts-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Keyboard shortcuts</a></span></li><li><span><a href="#Re-open-your-notebook-home" data-toc-modified-id="Re-open-your-notebook-home-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Re-open your notebook home</a></span></li><li><span><a href="#Magic-commands" data-toc-modified-id="Magic-commands-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Magic commands</a></span></li><li><span><a href="#nbextensions" data-toc-modified-id="nbextensions-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>nbextensions</a></span></li><li><span><a href="#ScratchPad-(Ctrl-B)" data-toc-modified-id="ScratchPad-(Ctrl-B)-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>ScratchPad (Ctrl-B)</a></span></li></ul></li><li><span><a href="#Jupyter-theme" data-toc-modified-id="Jupyter-theme-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Jupyter theme</a></span></li></ul></div>

# %% [markdown]
# # Using Jupyter
# ## Useful keyboard commands
# * `ctrl + Enter` to run a cell
# * `Alt + Enter` to run a cell and append a new cell below

# %%
x = 3
y = 123
print(x + y)
x + y
z = [1, 2, 3, 4, 5]
sum(z)
# Out:
# 126
# 15

# %% [markdown]
# # Look-up function doc

# %%
# ?sum

# %% [markdown]
# ## Auto-sugestion
# 1. **`tab`** to see what functions you can use
# 2.  **`shift-tab`** to check function argument

# %%
listA  = [1, 2, 3, 4, 5]
len(listA)
# Out:
# 5

# %%
listA.append(35)
listA
# Out:
# [1, 2, 3, 4, 5, 35]

# %% [markdown]
# # Tips
#
# ## Keyboard shortcuts
#
# * `Alt-Enter` runs the current cell and inserts a new one below.
# * `Ctrl-Enter` run the current cell and enters command mode.
#
# ## Re-open your notebook home
# * 通常你一開始在執行jupyter notebook後，會跳出一個命令列視窗，告訴你可以用哪個url開啟jupyter notebook。如果你不小心關了你的notebook home，不知道要怎麼重新打開時，就可以用這個網址打開。
# ```
# [I 09:19:07.526 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 09:19:07.527 NotebookApp]
#
#     Copy/paste this URL into your browser when you connect for the first time,
#     to login with a token:
#         http://localhost:8888/?token=2d0104cc02d813053bfe72128f0592f908d4d8e41cd9d617&token=2d0104cc02d813053bfe72128f0592f908d4d8e41cd9d617
# ```
#
# ## Magic commands
#
# * See https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
# * `%who` to show current global variables
# * `%whos` to show current global variables and their content
#
# ## nbextensions
#
# * You can install jupyter nbextensions to get more tools. Please visit [nbextension](https://github.com/ipython-contrib/jupyter_contrib_nbextensions) to install it.
#     * `pip install jupyter_contrib_nbextensions` from your terminal (WIN: cmd.exe)
#     * `conda install -c conda-forge jupyter_contrib_nbextensions`
# * You will see nbextensions appear in your jupyter notebook when you start jupyter notebook. I like following extensions
#     * Table of content
#     * ScratchPad
#     * Highlight selected word
# ![Pasted_Image_2020_2_21__21_57.png](attachment:Pasted_Image_2020_2_21__21_57.png)
#
# ## ScratchPad (Ctrl-B)
# ---

# %% [markdown]
# # Jupyter theme
# - Installing "[Jupyter themes](https://github.com/dunovank/jupyter-themes)"
# ```
# pip install jupyterthemes
# pip install --upgrade jupyterthemes
# ```
# - My favorite theme to-go:
# ```
# jt -t grade3 -fs 11 -ofs 11 -altp -tfs 13 -nfs 13 -cellw 80% -lineh 140 -cursw 4 -cursc r -altmd
# ```
# - Second theme
# ```
# jt -t grade3 -fs 11 -ofs 11 -altp -cellw 80% -lineh 140 -cursw 4 -cursc r
# ```
